# %% [markdown]
# ### Atelier Pandas

# %% [markdown]
# ##### Contexte
# Une entreprise possède plusieurs bâtiments équipés de capteurs IoT.
# Chaque capteur collecte régulièrement des informations sur la température, l'humidité, la pression,
# la consommation énergétique, l'état du capteur, le bâtiment, la date et l'heure de la mesure.
# Les données doivent être préparées et analysées avant d'être transmises à un futur système de
# Machine Learning permettant de détecter des situations anormales.

# %% [markdown]
# ##### Structuration du projet
#         1) Structuration le projet
#         2) Stocker le fichier fourni mesures_capteurs.csv dans le sous-dossier data
#         3) Créer le notebook atelier_pandas_iot.ipynb

# %%
import pandas as pd

# %% [markdown]
# #### Partie 1 – Series

# %% [markdown]
# ##### 1) Création d'une Series contenant 4 températures

# %%
serie_temp4 = pd.Series([12.25, 38.01, 5.8, 14.5])
serie_temp4
# Out:
# 0    12.25
# 1    38.01
# 2     5.80
# 3    14.50
# dtype: float64

# %% [markdown]
# ##### 2) Affichage de l'index de la série

# %%
print("L'index de la séerie : ",serie_temp4.index)
# Out:
# L'index de la séerie :  RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ##### 3) Affichage de la 1ère valeur de la série

# %%
print("La 1ére valeur de la série est : ", serie_temp4[0])
# Out:
# La 1ére valeur de la série est :  12.25

# %% [markdown]
# ##### 4) Affichage de la dernière valeur de la série

# %%
print("La dernière valeur de la série est : ", serie_temp4.iloc[-1])
# Out:
# La dernière valeur de la série est :  14.5

# %% [markdown]
# ##### 5) Création de deux façon différentes, une Series de 4 températures avec comme index les heures de mesure 12h, 13h, 14h et 15h

# %%
# Première maniére
serie_temp_h = pd.Series([21.5, 32, 7.03, 18], index=['12h', '13h', '14h', '15h'])

# Deuxiéme manière
dict = {'12h' : 21.5, '13h' : 32, '15h' : 7.03, '15h' : 18}
serie_temp_h = pd.Series(dict)
serie_temp_h
# Out:
# 12h    21.5
# 13h    32.0
# 15h    18.0
# dtype: float64

# %% [markdown]
# ##### 6) Affichage la 1ère et la dernière valeur

# %%
# 1e valeur
print("La 1ére valeur de la série est : ", serie_temp_h['12h'])

# dernière valeur
print("La dernière valeur de la série est : ", serie_temp_h.iloc[-1])
# Out:
# La 1ére valeur de la série est :  21.5
# La dernière valeur de la série est :  18.0

# %% [markdown]
# #### Partie 2 – DataFrame

# %% [markdown]
# ##### 1) Création et affichage du dataframe df_test à partir du dictionnaire suivant

# %%
# Création du dictionnaire df_test
data = { 
    "capteur": ["C001", "C002", "C003"], 
    "temperature": [24.5, 25.1, 26.3], 
    "humidite": [65, 67, 70] 
}

# %%
# Création et affichagedu DataFrame à partir du dictionnaire data
df_test = pd.DataFrame(data)
df_test
# Out:
#   capteur  temperature  humidite
# 0    C001         24.5        65
# 1    C002         25.1        67
# 2    C003         26.3        70

# %% [markdown]
# ##### 2) Importation du dataset mesures_capteurs.csv dans le dataframe df

# %%
df = pd.read_csv(r'C:\Users\cissc\OneDrive\Documents\P1IA_ODC\atelier_pandas\data\mesures_capteurs.csv')
# On ajoute un 'r' devant les guillemets pour éviter les erreurs de caractères)

# %% [markdown]
# ##### 3) Affichage les dimensions de df

# %%
print("Les dimensions : ", df.shape)
# Out:
# Les dimensions :  (605, 9)

# %% [markdown]
# NB : Dans la suite de l’atelier, on travaillera avec le dataframe df

# %% [markdown]
# #### Partie 3 – Exploration

# %% [markdown]
# ##### 1) Affichage des premières lignes

# %%
df.head()
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# 3   1019.62        136.65   OK
# 4   1016.58        182.62   OK

# %% [markdown]
# ##### 2) Affichage des 10 premières lignes

# %%
df.head(10)
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
# 5     M0595  2026-01-29 18:00:00       C007     B003        24.51     58.01
# 6     M0011  2026-01-05 10:00:00       C011     B004        29.23     70.43
# 7     M0132  2026-01-10 11:00:00       C012     B004        31.21     60.57
# 8     M0444  2026-01-23 11:00:00       C012     B004        23.11     82.06
# 9     M0087  2026-01-08 14:00:00       C003     B001        28.85     44.37
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# ...

# %% [markdown]
# ##### 3) Affichage les dernières lignes

# %%
df.tail()
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67     60.28
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34     61.42
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73     63.49
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83     79.77
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02     52.04
#
#      pression  consommation etat
# 600   1015.11        282.36   OK
# 601   1019.43        357.43   OK
# 602   1016.46        152.79   OK
# 603   1017.05        170.97   OK
# 604   1001.14         44.99   OK

# %% [markdown]
# ##### 4) Affichages des nombre de lignes

# %%
nb_lignes = len(df)         #  équivaut nb_lignes = df.shape[0]
print('Nombres de lignes de df : ', nb_lignes)
# Out:
# Nombres de lignes de df :  605

# %% [markdown]
# ##### 5) Affichage de nombre de colonnes

# %%
nb_colonnes = len(df.columns)       # équivaut  nb_colonnes = df.shape[1]
print('Nombres de colonnes de df : ', nb_colonnes)
# Out:
# Nombres de colonnes de df :  9

# %% [markdown]
# ##### 6) Affichage des noms des colonnes

# %%
print("Noms des colonnes : ",df.columns)
# Out:
# Noms des colonnes :  Index(['id_mesure', 'date_heure', 'id_capteur', 'batiment', 'temperature',
#        'humidite', 'pression', 'consommation', 'etat'],
#       dtype='object')

# %% [markdown]
# ##### 7) Affichage des informations générales

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_mesure     605 non-null    object
#  1   date_heure    605 non-null    object
#  2   id_capteur    605 non-null    object
#  3   batiment      605 non-null    object
#  4   temperature   599 non-null    float64
#  5   humidite      600 non-null    float64
#  6   pression      600 non-null    float64
#  7   consommation  600 non-null    float64
#  8   etat          601 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 42.7+ KB

# %% [markdown]
# ##### 8) Affichage des statistiques descriptives

# %%
df.describe()
# Out:
#        temperature   humidite     pression  consommation
# count   599.000000  600.00000   600.000000    600.000000
# mean     24.878314   64.92620  1012.221900    208.675417
# std       4.059576   10.76905    10.599042     72.243567
# min     -18.500000   28.52000   850.000000     18.120000
# 25%      22.570000   58.17250  1006.790000    160.177500
# 50%      24.860000   65.37500  1012.855000    206.150000
# 75%      27.275000   71.61500  1017.827500    254.127500
# max      58.700000  145.00000  1038.430000    875.000000

# %%
# Variabloes Catégorielles
df.describe(include='object')
# Out:
#        id_mesure           date_heure id_capteur batiment etat
# count        605                  605        605      605  601
# unique       600                  600         12        4    3
# top        M0599  2026-01-29 22:00:00       C002     B001   OK
# freq           2                    2         52      153  567

# %% [markdown]
# #### Partie 4 – Sélection

# %% [markdown]
# ##### 1) Sélection de la colonne "temperature"

# %%
df['temperature']
# Out:
# 0      25.46
# 1      24.00
# 2      25.82
# 3      28.23
# 4      20.58
#        ...
# 600    23.67
# 601    24.34
# 602    23.73
# 603    24.83
# 604    17.02
# Name: temperature, Length: 605, dtype: float64

# %% [markdown]
# ##### 2) Sélection des colonnes "temperature", "humidite", "pression" et "consommation"

# %%
df[["temperature", "humidite", "pression" , "consommation"]]
# Out:
#      temperature  humidite  pression  consommation
# 0          25.46     58.06   1008.95        287.28
# 1          24.00     79.73    993.39        116.20
# 2          25.82     54.47   1010.32        288.50
# 3          28.23     69.39   1019.62        136.65
# 4          20.58     53.80   1016.58        182.62
# ..           ...       ...       ...           ...
# 600        23.67     60.28   1015.11        282.36
# 601        24.34     61.42   1019.43        357.43
# 602        23.73     63.49   1016.46        152.79
# 603        24.83     79.77   1017.05        170.97
# 604        17.02     52.04   1001.14         44.99
#
# [605 rows x 4 columns]

# %% [markdown]
# ##### 3) Sélectionner les 5 premières lignes avec loc

# %%
df.loc[:4]
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# 3   1019.62        136.65   OK
# 4   1016.58        182.62   OK

# %% [markdown]
# ##### 4) Sélectionner les 5 premières lignes et les 4 premières colonnes avec iloc

# %%
df.iloc[:5]
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# 3   1019.62        136.65   OK
# 4   1016.58        182.62   OK
